# %%
import pandas as pd

# %%
url = r"https://raw.githubusercontent.com/AkshaanB/JanataHack-Machine-Learning-for-Banking/master/dataset/train_data.csv?token=AMWGGDPXWP725STCHPPLQCS646AZG"

# %%
df_data = pd.read_csv(url)
df_data
# Out:
#          Loan_ID Loan_Amount_Requested Length_Employed Home_Owner  \
# 0       10000001                 7,000        < 1 year       Rent
# 1       10000002                30,000         4 years   Mortgage
# 2       10000003                24,725         7 years   Mortgage
# 3       10000004                16,000        < 1 year        NaN
# 4       10000005                17,000         8 years        Own
# ...          ...                   ...             ...        ...
# 164304  10164305                20,725       10+ years       Rent
# 164305  10164306                 6,000         8 years        Own
# 164306  10164307                20,250       10+ years   Mortgage
# 164307  10164308                10,000         4 years       Rent
# 164308  10164309                 9,250       10+ years       Rent
#
#         Annual_Income           Income_Verified     Purpose_Of_Loan  \
# 0             68000.0              not verified                 car
# ...

# %%
df_data.shape
# Out:
# (164309, 14)

# %%
df_data.dtypes
# Out:
# Loan_ID                      int64
# Loan_Amount_Requested       object
# Length_Employed             object
# Home_Owner                  object
# Annual_Income              float64
# Income_Verified             object
# Purpose_Of_Loan             object
# Debt_To_Income             float64
# Inquiries_Last_6Mo           int64
# Months_Since_Deliquency    float64
# Number_Open_Accounts         int64
# Total_Accounts               int64
# Gender                      object
# Interest_Rate                int64
# dtype: object

# %%
df_data.isnull().sum()
# Out:
# Loan_ID                        0
# Loan_Amount_Requested          0
# Length_Employed             7371
# Home_Owner                 25349
# Annual_Income              25102
# Income_Verified                0
# Purpose_Of_Loan                0
# Debt_To_Income                 0
# Inquiries_Last_6Mo             0
# Months_Since_Deliquency    88379
# Number_Open_Accounts           0
# Total_Accounts                 0
# Gender                         0
# Interest_Rate                  0
# dtype: int64

# %%
df_data['Length_Employed'].unique()
# Out:
# array(['< 1 year', '4 years', '7 years', '8 years', '2 years',
#        '10+ years', '1 year', nan, '6 years', '9 years', '3 years',
#        '5 years'], dtype=object)

# %%
df_data['Length_Employed_new'] = df_data['Length_Employed'].str.rstrip(" years")
df_data
# Out:
#          Loan_ID Loan_Amount_Requested Length_Employed Home_Owner  \
# 0       10000001                 7,000        < 1 year       Rent
# 1       10000002                30,000         4 years   Mortgage
# 2       10000003                24,725         7 years   Mortgage
# 3       10000004                16,000        < 1 year        NaN
# 4       10000005                17,000         8 years        Own
# ...          ...                   ...             ...        ...
# 164304  10164305                20,725       10+ years       Rent
# 164305  10164306                 6,000         8 years        Own
# 164306  10164307                20,250       10+ years   Mortgage
# 164307  10164308                10,000         4 years       Rent
# 164308  10164309                 9,250       10+ years       Rent
#
#         Annual_Income           Income_Verified     Purpose_Of_Loan  \
# 0             68000.0              not verified                 car
# ...

# %%
df_data['Length_Employed_new'] = df_data['Length_Employed_new'].str.rstrip("+")
df_data['Length_Employed_new'] = df_data['Length_Employed_new'].str.lstrip("< ")
df_data
# Out:
#          Loan_ID Loan_Amount_Requested Length_Employed Home_Owner  \
# 0       10000001                 7,000        < 1 year       Rent
# 1       10000002                30,000         4 years   Mortgage
# 2       10000003                24,725         7 years   Mortgage
# 3       10000004                16,000        < 1 year        NaN
# 4       10000005                17,000         8 years        Own
# ...          ...                   ...             ...        ...
# 164304  10164305                20,725       10+ years       Rent
# 164305  10164306                 6,000         8 years        Own
# 164306  10164307                20,250       10+ years   Mortgage
# 164307  10164308                10,000         4 years       Rent
# 164308  10164309                 9,250       10+ years       Rent
#
#         Annual_Income           Income_Verified     Purpose_Of_Loan  \
# 0             68000.0              not verified                 car
# ...

# %%
df_data['Length_Employed_new'] = df_data['Length_Employed_new'].fillna(0)

# %%
df_data['Length_Employed_new'].unique()
# Out:
# array(['1', '4', '7', '8', '2', '10', 0, '6', '9', '3', '5'], dtype=object)

# %%
df_data['Length_Employed_new'].value_counts()
# Out:
# 10    52915
# 1     23227
# 2     14620
# 3     12974
# 5     10814
# 4      9784
# 7      9308
# 6      9094
# 8      7917
# 0      7371
# 9      6285
# Name: Length_Employed_new, dtype: int64

# %%
df_data['Length_Employed_new'] = df_data['Length_Employed_new'].astype('int')

# %%
df_data.dtypes
# Out:
# Loan_ID                      int64
# Loan_Amount_Requested       object
# Length_Employed             object
# Home_Owner                  object
# Annual_Income              float64
# Income_Verified             object
# Purpose_Of_Loan             object
# Debt_To_Income             float64
# Inquiries_Last_6Mo           int64
# Months_Since_Deliquency    float64
# Number_Open_Accounts         int64
# Total_Accounts               int64
# Gender                      object
# Interest_Rate                int64
# Length_Employed_new          int32
# dtype: object

# %%
df_data['Length_Employed_new'] = df_data['Length_Employed_new'].replace(to_replace=[0], value= df_data['Length_Employed_new'].mode())

# %%
df_data.drop(['Length_Employed'], axis=1,inplace=True)

# %%
df_data
# Out:
#          Loan_ID Loan_Amount_Requested Home_Owner  Annual_Income  \
# 0       10000001                 7,000       Rent        68000.0
# 1       10000002                30,000   Mortgage            NaN
# 2       10000003                24,725   Mortgage        75566.4
# 3       10000004                16,000        NaN        56160.0
# 4       10000005                17,000        Own        96000.0
# ...          ...                   ...        ...            ...
# 164304  10164305                20,725       Rent            NaN
# 164305  10164306                 6,000        Own            NaN
# 164306  10164307                20,250   Mortgage            NaN
# 164307  10164308                10,000       Rent            NaN
# 164308  10164309                 9,250       Rent            NaN
#
#                  Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# 0                   not verified                 car           18.37
# ...

# %%
df_data.isnull().sum()
# Out:
# Loan_ID                        0
# Loan_Amount_Requested          0
# Home_Owner                 25349
# Annual_Income              25102
# Income_Verified                0
# Purpose_Of_Loan                0
# Debt_To_Income                 0
# Inquiries_Last_6Mo             0
# Months_Since_Deliquency    88379
# Number_Open_Accounts           0
# Total_Accounts                 0
# Gender                         0
# Interest_Rate                  0
# Length_Employed_new            0
# dtype: int64

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df_data['Gender'] = label_encoder.fit_transform(df_data['Gender'].astype(str))

# %%
df_data
# Out:
#          Loan_ID Loan_Amount_Requested Home_Owner  Annual_Income  \
# 0       10000001                 7,000       Rent        68000.0
# 1       10000002                30,000   Mortgage            NaN
# 2       10000003                24,725   Mortgage        75566.4
# 3       10000004                16,000        NaN        56160.0
# 4       10000005                17,000        Own        96000.0
# ...          ...                   ...        ...            ...
# 164304  10164305                20,725       Rent            NaN
# 164305  10164306                 6,000        Own            NaN
# 164306  10164307                20,250   Mortgage            NaN
# 164307  10164308                10,000       Rent            NaN
# 164308  10164309                 9,250       Rent            NaN
#
#                  Income_Verified     Purpose_Of_Loan  Debt_To_Income  \
# 0                   not verified                 car           18.37
# ...

# %%
df_data.dtypes
# Out:
# Loan_ID                      int64
# Loan_Amount_Requested       object
# Home_Owner                  object
# Annual_Income              float64
# Income_Verified             object
# Purpose_Of_Loan             object
# Debt_To_Income             float64
# Inquiries_Last_6Mo           int64
# Months_Since_Deliquency    float64
# Number_Open_Accounts         int64
# Total_Accounts               int64
# Gender                       int32
# Interest_Rate                int64
# Length_Employed_new          int64
# dtype: object

# %%
df_data['Purpose_Of_Loan'].unique()
# Out:
# array(['car', 'debt_consolidation', 'credit_card', 'home_improvement',
#        'major_purchase', 'other', 'medical', 'small_business', 'moving',
#        'wedding', 'vacation', 'house', 'educational', 'renewable_energy'],
#       dtype=object)

# %%
df_data['Income_Verified'].unique()
# Out:
# array(['not verified', 'VERIFIED - income', 'VERIFIED - income source'],
#       dtype=object)

# %%
df_data = pd.get_dummies(df_data, columns=['Income_Verified'])

# %%
df_data
# Out:
#          Loan_ID Loan_Amount_Requested Home_Owner  Annual_Income  \
# 0       10000001                 7,000       Rent        68000.0
# 1       10000002                30,000   Mortgage            NaN
# 2       10000003                24,725   Mortgage        75566.4
# 3       10000004                16,000        NaN        56160.0
# 4       10000005                17,000        Own        96000.0
# ...          ...                   ...        ...            ...
# 164304  10164305                20,725       Rent            NaN
# 164305  10164306                 6,000        Own            NaN
# 164306  10164307                20,250   Mortgage            NaN
# 164307  10164308                10,000       Rent            NaN
# 164308  10164309                 9,250       Rent            NaN
#
#            Purpose_Of_Loan  Debt_To_Income  Inquiries_Last_6Mo  \
# 0                      car           18.37                   0
# ...

# %%
import numpy as np

# %%
df_data['Length_Employed'].replace(np.nan, df_data['Length_Employed'].mode(), inplace=True)

# %%
df_data['Months_Since_Deliquency'].replace(np.nan, df_data['Months_Since_Deliquency'].mean(), inplace=True)

# %%
df_data.isnull().sum()
# Out:
# Loan_ID                        0
# Loan_Amount_Requested          0
# Length_Employed             7371
# Home_Owner                 25349
# Annual_Income              25102
# Income_Verified                0
# Purpose_Of_Loan                0
# Debt_To_Income                 0
# Inquiries_Last_6Mo             0
# Months_Since_Deliquency        0
# Number_Open_Accounts           0
# Total_Accounts                 0
# Gender                         0
# Interest_Rate                  0
# dtype: int64

# %%
df_data.dropna(inplace=True)

# %%
df_data.isnull().sum()
# Out:
# Loan_ID                    0
# Loan_Amount_Requested      0
# Length_Employed            0
# Home_Owner                 0
# Annual_Income              0
# Income_Verified            0
# Purpose_Of_Loan            0
# Debt_To_Income             0
# Inquiries_Last_6Mo         0
# Months_Since_Deliquency    0
# Number_Open_Accounts       0
# Total_Accounts             0
# Gender                     0
# Interest_Rate              0
# dtype: int64

# %%
df_data
# Out:
#          Loan_ID Loan_Amount_Requested Length_Employed Home_Owner  \
# 7       10000008                15,000        < 1 year       Rent
# 12      10000013                 7,200       10+ years       Rent
# 14      10000015                 6,700       10+ years   Mortgage
# 18      10000019                25,000       10+ years       Rent
# 20      10000021                 4,000       10+ years       Rent
# ...          ...                   ...             ...        ...
# 164285  10164286                 7,200         6 years   Mortgage
# 164287  10164288                25,000       10+ years   Mortgage
# 164288  10164289                 6,000         2 years       Rent
# 164300  10164301                24,000          1 year       Rent
# 164303  10164304                35,000       10+ years       Rent
#
#         Annual_Income           Income_Verified     Purpose_Of_Loan  \
# 7            115000.0         VERIFIED - income  debt_consolidation
# ...
